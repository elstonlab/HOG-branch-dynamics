# %% [markdown]
# # Import packages and set settings

# %%
# %load_ext autoreload
# %autoreload 2

import sys
# sys.path.insert(1, './python_mods/')
sys.path.insert(1, '../python_modules')
import plotting
import model_supp 
import model

# %%
# %matplotlib inline
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd
import os
import collections
import h5py

# %%
# plt.style.use("seaborn-whitegrid")
plt.rcParams['figure.figsize'] = [10.0, 8.0]
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['legend.fontsize'] = 10
colors = [i['color'] for i in plt.rcParams['axes.prop_cycle']]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Variables (Constants)

# %%
dt = 0.1
steps = 601
time = np.linspace(0,dt*steps,steps)

# Protein concentrations (mM) #2
Sln1_tot = model_supp.molarity_conversion(1176)
Sho1_tot = model_supp.molarity_conversion(1534)
Hog1_tot = model_supp.molarity_conversion(8225)
total_protein = [Sln1_tot, Sho1_tot, Hog1_tot, 0] #mM

# initial values
Sln1 = 0
Sho1 = 0
Hog1_AC = 0
Hog1_AN = 0
Hog1_IN = 0.23 * Hog1_tot
Glycerol = 0.0001
inits = [Sln1, Sho1, Hog1_AC, Hog1_AN, Hog1_IN, Glycerol]

# doses
doses = [150, 350, 550]

# Parameter ranges
number_of_params = 28
minimums = [-8, 0, -4, 0, -8,
        -4, 0, 0, -8, -8,
        0, -8, -8, -8, -2,
        -4, 0, -4, -2, -4,
        -8, 0, -4, -4, 0,
        -8, -8, 0
        ]

maximums = [0, 8, 6, 8, 0,
        4, 8, 8, 0, 0,
        8, 0, 0, 0, 6,
        4, 8, 4, 6, 4,
        0, 8, 4, 4, 8,
        0, 2, 8
        ]

labelnames = ['$baseosmo$', '$k1$', '$K1$', '$k2$', '$K2$', 
              '$k3$', '$K3$', '$k4$', '$K4$', '$k5$', '$k6$','$K56$',
              '$k7$', '$K7$', '$k8$','$K8$','$k9A$','$K9a$','$k9B$','$K9b$','$k10$', '$K10$', 
              '$k11$','$K11$','$k12$', '$k13$', '$k14$', '$k15$']

diff = np.asarray(maximums)-np.asarray(minimums) #for plotting
dims = (diff, minimums) #for plotting

# %% [markdown]
# # Load experimental data

# %%
exp_data, exp_time = model_supp.get_data(input='60perc')

wt_phospho_data, wt_nuc_data = exp_data
phospho_time, nuc_time = exp_time

# %% [markdown]
# # Load simulation data

# %%
model_fxns = model.Model(model.OM_Sho1imp)

# %%
folder = '../sim_data/200518_OptimizedModel_Sho1imp_60'

all_params, last_params, all_mses, last_mses = model_supp.get_sim_data(folder, num_sims=2000)
sorted_mses_EA, sorted_thetas_EA = model_supp.sort_mses_thetas(last_mses, last_params)
# Out:
# Number of runs collected: 487
# Best last gen MSE: 867.4659713442081
# Mean last gen MSEs of top 5%: 1306.387598205866

# %% [markdown]
# # Saving info

# %%
base_save_f = 'C:/Users/sksuzuki/Documents/Research/Thesis/Dissertation/Figures/Chapter 3/Figure 2/'

# %% [markdown]
# # Check EA results

# %%
plotting.plt_mses_gen(200, all_mses, 50)

# %%
plotting.plt_idx_vs_mse(sorted_mses_EA, len(sorted_mses_EA))
# Out:
# No handles with labels found to put in legend.

# %%
plotting.plt_idx_vs_mse(sorted_mses_EA, 100)
# Out:
# No handles with labels found to put in legend.

# %%
plotting.plt_param_cis(model_fxns, sorted_thetas_EA[0:7], total_protein, inits,  doses, time, param='phospho',
                        exp_data=wt_phospho_data, exp_time=phospho_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# Dose: 150 complete.
# Dose: 350 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
test = sorted_thetas_EA[0:7].copy()
# test = [(x[-1]=0) for x in test]
for x in test:
    x[-1] = 0
print(test)
# Out:
# [[1.43599766e-01 4.35407315e+02 3.08650107e+03 2.20304266e+02
#   3.36488714e-04 5.57356876e-01 1.03142281e+03 2.68107908e+03
#   1.31075179e-08 9.00044370e-01 2.42298908e+07 3.35200729e-03
#   9.99354284e-01 6.93321228e-03 5.46767912e-01 2.02409619e-03
#   5.64017812e+01 4.03692022e+00 2.07903492e+02 6.87953233e-01
#   3.63753141e-07 6.14707679e+07 8.28909816e+00 1.97330903e+00
#   3.82817296e+07 5.52199657e-04 1.57881711e+01 0.00000000e+00]
#  [8.49812140e-02 7.34075264e+07 1.73332442e-04 5.69029634e+02
#   9.99945647e-01 5.08141876e+03 3.95722716e+00 2.36420693e+00
#   3.91797969e-07 1.96522807e-04 3.91177679e+06 3.28554216e-02
#   9.71039213e-01 8.59983126e-03 1.02757792e-01 6.48682315e-02
#   1.03235926e+02 6.94087177e-03 5.45531006e+03 2.89780409e+03
#   2.70486721e-08 1.85964884e+03 2.37064243e+03 5.62465069e-01
#   9.99994351e+07 1.15275377e-03 9.94017109e+01 0.00000000e+00]
#  [6.28222942e-01 5.31342636e+03 4.74429499e+00 5.41561565e+02
#   1.63405388e-04 9.99469702e+03 3.62399877e+04 1.57102588e+04
#   1.27061436e-08 3.44250266e-03 2.46056936e+07 4.89688354e-03
#   1.09334182e-01 1.72490197e-03 2.94527491e+01 1.19521438e+00
#   1.60157349e+03 1.24600821e+00 2.17903870e+01 8.51387803e-01
#   4.07092505e-01 4.82146093e+04 1.97508530e+03 4.96125712e+00
#   9.77228654e+07 6.61289379e-05 3.86862874e-08 0.00000000e+00]
#  [1.83676162e-05 1.60443357e+04 3.98212929e+01 4.56455667e+02
#   2.99466742e-02 2.08874063e-04 2.03915640e+00 1.17083173e+02
#   7.33482953e-07 1.24699182e-08 5.14434717e+07 1.46263797e-02
#   9.97437144e-01 3.53020777e-04 9.63783228e+05 6.85991726e-02
#   1.46626745e+01 3.80609131e-03 3.07964368e+03 1.00001402e-04
#   1.24228202e-07 9.41533714e+05 6.91648221e+03 6.21037095e+00
#   8.28227452e+07 7.91873078e-04 1.58056668e+01 0.00000000e+00]
#  [6.10943883e-07 3.23309471e+07 1.14675985e-04 8.82522329e+00
#   3.05029945e-01 2.59727582e+03 6.72175466e+00 1.28088008e+00
#   1.12131154e-08 9.84836802e-01 2.65066079e+07 2.49541907e-05
#   2.34597413e-01 9.79559650e-04 4.24975947e+03 1.22046652e-03
#   1.08424114e+00 8.71249522e-01 6.68399164e+02 1.00938868e-04
#   9.78340860e-02 9.78392403e+07 3.49575768e-01 9.24127474e-01
#   1.69101919e+06 8.99778701e-04 1.34983373e-02 0.00000000e+00]
#  [9.44096431e-03 1.68286764e+05 9.07964728e+05 2.62267892e+02
#   9.92674925e-01 3.03310552e-03 5.25455282e+07 3.85422889e+02
#   7.56073602e-03 8.99621014e-01 3.42004012e+03 1.20050307e-08
#   7.99730734e-02 3.99518569e-05 1.93172567e+00 1.80451795e-04
#   3.26402654e+00 1.62864083e-04 9.17468855e+03 2.66695747e-01
#   3.25768069e-04 1.26333669e+01 5.36212910e+01 1.26302229e-02
#   4.08311998e+07 4.22935834e-08 1.75937356e+00 0.00000000e+00]
#  [9.68994736e-01 7.57584493e+05 5.17771211e+03 3.35569669e+01
#   4.74959575e-07 7.86785150e+03 1.44111908e+01 3.22078986e+03
#   1.06676840e-07 1.00109837e-03 1.06157610e+05 3.76524258e-02
#   1.40284777e-03 1.12705813e-03 7.60572075e+03 2.51065816e-01
#   1.20373177e+02 5.77619354e+01 1.62072241e+03 4.95757455e-02
#   2.55715844e-01 1.96341300e+00 2.92291892e-02 4.86990104e-02
#   5.44039136e+06 4.52736589e-06 1.53324205e-08 0.00000000e+00]]

# %%
plotting.plt_param_cis(model_fxns, test, total_protein, inits,  doses, time, param='nuc',      
                        exp_data=wt_nuc_data, exp_time=nuc_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\numpy\core\_methods.py:116: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# Dose: 150 complete.
# Dose: 350 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_param_cis(model_fxns, sorted_thetas_EA[0:7], total_protein, inits,  doses, time, param='nuc',      
                        exp_data=wt_nuc_data, exp_time=nuc_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# Dose: 150 complete.
# Dose: 350 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
# plotting.plt_param_cis(model_fxns, sorted_thetas_EA[0:7], total_protein, inits,  doses, time, param='nuc',      
#                         exp_data=wt_nuc_data, exp_time=nuc_time, ss=True, ci='sd',
#                         save_fig='')

# %%
# PLOT INDIVIDUAL SIMS
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits,  doses, time, 'phospho', wt_phospho_data, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 7, total_protein, inits,  doses, time, 'phospho', wt_nuc_data, mapk_time=nuc_time,ss=True)

# %%
# PLOT INDIVIDUAL SIMS
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 7, total_protein, inits,  doses, time, 'phospho', wt_nuc_data, mapk_time=nuc_time,ss=True)

# %%
# PLOT INDIVIDUAL SIMS
plotting.plt_param_behaviors(model_fxns, test, 7, total_protein, inits,  doses, time, 'phospho', wt_nuc_data, mapk_time=nuc_time,ss=True)
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ../python_modules\plotting.py:174: RuntimeWarning: overflow encountered in true_divide
#   phospho = (data[:,2]+data[:,3])/params_constants[2]*100
# ../python_modules\plotting.py:174: RuntimeWarning: overflow encountered in multiply
#   phospho = (data[:,2]+data[:,3])/params_constants[2]*100
# ../python_modules\plotting.py:175: RuntimeWarning: overflow encountered in true_divide
#   nuc = (data[:,3]+data[:,4])/params_constants[2]*100
# ../python_modules\plotting.py:175: RuntimeWarning: overflow encountered in multiply
#   nuc = (data[:,3]+data[:,4])/params_constants[2]*100

# %%
#sho1 only
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits,  doses, time, 'sho1', mapk_wt_data=None, mapk_time=nuc_time,ss=True)

# %%
# sln1 only
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits,  doses, time, 'sln1', mapk_wt_data=None, mapk_time=nuc_time,ss=True)

# %%
# sln1 only
sln1 = sorted_thetas_EA[0].copy()
sln1[10]=0
plotting.plt_param_behaviors(model_fxns, np.array([sln1]), 1, total_protein, inits,  doses, time, 'phospho', wt_phospho_data, mapk_time=phospho_time,ss=True)

# %%
# sho1 only
sho1 = sorted_thetas_EA[0].copy()
sho1[9]=0
plotting.plt_param_behaviors(model_fxns, np.array([sho1]), 1, total_protein, inits,  doses, time, 'phospho', wt_phospho_data, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [150], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_integrals(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [150], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [350], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_integrals(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [350], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [550], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %%
plotting.plt_param_integrals(model_fxns, sorted_thetas_EA, 1, total_protein, inits, [550], time, 'all Hog1', mapk_wt_data=None, mapk_time=phospho_time,ss=True)

# %% [markdown]
# ## Separate species

# %%
plotting.plt_all_hog1_cis(model_fxns, sorted_thetas_EA[0:5], total_protein, inits,  150, time, param='all Hog1',      
                        exp_data=None, exp_time=None, ss=True, ci='sd',
                        save_fig=base_save_f+'Fig2D1')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_all_hog1_cis(model_fxns, sorted_thetas_EA[0:5], total_protein, inits,  350, time, param='all Hog1',      
                        exp_data=None, exp_time=None, ss=True, ci='sd',
                        save_fig=base_save_f+'Fig2D2')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
plotting.plt_all_hog1_cis(model_fxns, sorted_thetas_EA[0:5], total_protein, inits,  550, time, param='all Hog1',      
                        exp_data=None, exp_time=None, ss=True, ci='sd',
                        save_fig=base_save_f+'Fig2D3')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
df_top_thetas_EA = pd.DataFrame(sorted_thetas_EA)
df_top_thetas_EA.columns = labelnames

xnum_plt = 0
num_plt = 10
df_plt = sorted_thetas_EA[xnum_plt:num_plt]
df_plt = pd.DataFrame(sorted_thetas_EA[xnum_plt:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')
plotting.plt_param_ranges(labelnames, 'M19', dims, df_plt_log_M, single_theta=df_plt_log, num=0) #black dot is best param
#print(df_plt)

# %%
sns.distplot(np.log10(df_top_thetas_EA[labelnames[3]]))

# %% [markdown]
# # Check ABC - SMC

# %%
base_folder = 'C:/Users/sksuzuki/Documents/GitHub/HOG_encoding_feedbacks/python_modules/ABC_SMC/200121_M3c_ea_abc_smc/'

ea = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0000.hdf5', 'r')

# %%
list(ea.keys())
# Out:
# ['mses', 'thetas']

# %%
ea_thetas = ea['thetas']
ea_mses = ea['mses']

# %%
plotting.plt_param_cis(model_fxns, ea_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
e1 = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0001.hdf5', 'r')

# %%
e1_thetas = e1['thetas']
e1_mses = e1['mses']

# %%
plotting.plt_param_cis(M2c_fxns, e1_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
e4 = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0004.hdf5', 'r')

e4_thetas = e4['thetas']
e4_mses = e4['mses']

# %%
plotting.plt_param_cis(M2c_fxns, e4_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='test03')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
