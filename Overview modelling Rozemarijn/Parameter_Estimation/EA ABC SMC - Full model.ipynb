# %% [markdown]
# # Import packages and set settings

# %%
# %load_ext autoreload
# %autoreload 2

import sys
# sys.path.insert(1, './python_mods/')
sys.path.insert(1, 'python_modules')
import plotting
import model_supp 
import model

# %%
# %matplotlib inline
import pathlib
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd
import os
import collections
import h5py

# %%
# plt.style.use("seaborn-whitegrid")
plt.rcParams['figure.figsize'] = [10.0, 8.0]
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['grid.linestyle'] = '-'
plt.rcParams['legend.fontsize'] = 14
colors = [i['color'] for i in plt.rcParams['axes.prop_cycle']]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Variables (Constants)

# %%
dt = 0.1
steps = 601
time = np.linspace(0,dt*steps,steps)

# Protein concentrations (mM)
#Sln1_tot = model_supp.molarity_conversion(1176)
#Sho1_tot = model_supp.molarity_conversion(1534)
#Hog1_tot = model_supp.molarity_conversion(8225)
#total_protein = [Sln1_tot, Sho1_tot, Hog1_tot, 0] #mM

# Protein concentrations (mM)
Sho1_tot = model_supp.molarity_conversion(1534)
Hog1_tot = model_supp.molarity_conversion(8225)
total_protein = [Sho1_tot, Hog1_tot,0] #mM

# initial values
#Sln1 = 0
#Sho1 = 0
#Hog1_AC = 0
#Hog1_AN = 0
#Hog1_IN = 0.23 * Hog1_tot
#Glycerol = 0.0001
#inits = [Sln1, Sho1, Hog1_AC, Hog1_AN, Hog1_IN, Glycerol]

# initial values
Sho1 = 0
Hog1_AC = 0
Hog1_AN = 0
Hog1_IN = 0.23 * Hog1_tot
Glycerol = 0.0001
inits = [Sho1, Hog1_AC, Hog1_AN, Hog1_IN, Glycerol]

# doses
doses = [150, 350, 550]

# Parameter ranges
number_of_params = 28
minimums = [-8, 0, -4, 0, -8,
        -4, 0, 0, -8, -8,
        -8, -8, -8, -8, -8,
        -8, -8, -8, -8, -8,
        -8, -8, -8, -8, 0,
        -8, -8, 0
        ]

maximums = [0, 8, 6, 8, 0,
        4, 8, 8, 0, 8,
        8, 8, 8, 8, 8,
        8, 8, 8, 8, 8,
        8, 8, 8, 8, 8,
        0, 2, 8
        ]

labelnames = ['$baseosmo$', '$k1$', '$K1$', '$k2$', '$K2$', '$k3$', '$K3$',
              '$k4$', '$K4$', '$k5$', '$k6$', '$K56$', '$k7$', '$K7$',
              '$k8$','$K8$','$k9A$','$K9a$','$k9B$','$K9b$','$k10$', '$K10$', 
              '$k11$', '$K11$', '$k12$', '$k13$', '$k14$', '$k15$']

diff = np.asarray(maximums)-np.asarray(minimums) #for plotting
dims = (diff, minimums) #for plotting

# %% [markdown]
# # Load experimental data

# %%
exp_data, exp_time = model_supp.get_data(input='60perc')

wt_phospho_data, wt_nuc_data = exp_data
phospho_time, nuc_time = exp_time

# %% [markdown]
# # Load simulation data

# %%
model_fxns = model.Model(model.T12456)

# %%
folder = 'C:/Users/Rozemarijn/Documents/Universiteit/Masterstage2/Research/Modelling/Simulations/Simulation_data/Translocation/200528_OM1_1_2_4_5_6'

all_params, last_params, all_mses, last_mses = model_supp.get_sim_data(folder, num_sims=2000)
sorted_mses_EA, sorted_thetas_EA = model_supp.sort_mses_thetas(last_mses, last_params)
# Out:
# Number of runs collected: 969
# Best last gen MSE: 1117.1250168796842
# Mean last gen MSEs of top 5%: 1439.136704571017

# %% [markdown]
# # Check EA results

# %%
plotting.plt_mses_gen(200, all_mses, 10)

# %%
plotting.plt_idx_vs_mse(sorted_mses_EA, len(sorted_mses_EA))
# Out:
# No handles with labels found to put in legend.

# %%
plotting.plt_idx_vs_mse(sorted_mses_EA, 100)
#print(sorted_mses_EA[1])
# Out:
# No handles with labels found to put in legend.

# %%
#sorted_thetas_EA=np.delete(sorted_thetas_EA,0,0)
plotting.plt_param_integrals(model_fxns, sorted_thetas_EA[0:1],total_protein, inits,  doses, time, param='exp',
                        ci='sd',
                        save_fig='zoomintegral123456')
# Out:
# C:\Users\Rozemarijn\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150 complete.
# Dose: 350 complete.
# Dose: 550 complete.

# %%
#sorted_thetas_EA=np.delete(sorted_thetas_EA,1,0)
plotting.plt_param_cis(model_fxns, sorted_thetas_EA[0:10], total_protein, inits,  doses, time, param='phospho',
                        exp_data=wt_phospho_data, exp_time=phospho_time, ss=True, ci='sd',
                        save_fig='I_phospho')
# Out:
# Dose: 150 complete.
# Dose: 350 complete.
# Dose: 550 complete.

# %%
#sorted_thetas_EA=np.delete(sorted_thetas_EA,6,0)
plotting.plt_param_cis(model_fxns, sorted_thetas_EA[0:10], total_protein, inits,  doses, time, param='nuc',      
                        exp_data=wt_nuc_data, exp_time=nuc_time, ss=True, ci='sd',
                        save_fig='I_nuc')
# Out:
# Dose: 150 complete.
# C:\Users\Rozemarijn\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350 complete.
# C:\Users\Rozemarijn\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:247: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Dose: 550 complete.

# %%
# PLOT INDIVIDUAL SIMS
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 1, total_protein, inits,  doses, time, 'phospho', wt_phospho_data, mapk_time=phospho_time,ss=True)

# %%
# PLOT INDIVIDUAL SIMS
plotting.plt_param_behaviors(model_fxns, sorted_thetas_EA, 10, total_protein, inits,  doses, time, 'nuc', wt_nuc_data, mapk_time=nuc_time,ss=True)

# %%
df_top_thetas_EA = pd.DataFrame(sorted_thetas_EA)
df_top_thetas_EA.columns = labelnames

xnum_plt = 0
num_plt = 10
df_plt = sorted_thetas_EA[xnum_plt:num_plt]
df_plt = pd.DataFrame(sorted_thetas_EA[xnum_plt:num_plt])
df_plt.columns = labelnames
df_plt_log = df_plt.apply(np.log10)
df_plt_log_M = df_plt_log.melt(var_name='param', value_name='vals')
plotting.plt_param_ranges(labelnames, 'M19', dims, df_plt_log_M, single_theta=df_plt_log, num=0) #black dot is best param
#print(df_plt)

# %%
df_top_thetas_EA = pd.DataFrame(sorted_thetas_EA)
df_top_thetas_EA.columns = labelnames

xnum_plt = 0
num_plt = 472
df_plt = sorted_thetas_EA[xnum_plt:num_plt]
k9b = df_plt[:,13]/df_plt[:,14]
k10 = df_plt[:,15]/df_plt[:,16]
print(k9b)
print(k10)
# Out:
# [9.46913071e-01 1.69128457e+06 2.92988593e+09 2.80772761e+05
#  1.84951194e+05 2.78688168e+02 2.67091488e+10 2.88047168e-14
#  3.73490876e+02 2.42277547e-07 1.30377869e+02 2.85074343e+04
#  7.60516735e+10 8.26295531e-15 8.16656259e-16 1.15008285e-12
#  6.14576249e-10 1.01317992e-16 6.58858097e-06 7.32791010e-12
#  1.71842636e-01 1.54828534e-13 1.97944310e-13 2.99327894e-13
#  9.80914721e-02 1.07851647e+00 4.34052683e-13 9.34172164e-03
#  4.68025667e-14 6.51773498e+07 1.22153738e-08 2.21139026e-14
#  9.14783262e+00 1.07665351e+02 2.47507180e-02 1.32555993e+03
#  1.11556615e+02 1.28466541e-10 3.55241618e+02 5.94282446e+10
#  2.38930125e-11 6.64233458e+04 1.87292955e+09 4.33112522e+00
#  3.88896433e-15 5.06619008e-01 1.59234771e+11 2.05373811e+10
#  3.25535069e+09 4.39564818e+00 5.18578993e-10 5.05163606e-05
#  2.02945329e+14 1.72935670e+00 8.05294220e+01 1.98616169e+03
#  4.24186211e+01 2.28281282e+06 1.44772297e+06 2.59958807e-07
#  9.01439796e-01 1.58384526e-14 9.44341002e-04 8.41314312e-01
#  1.16696368e+08 8.14798291e-12 5.03708168e-13 1.97276257e-02
#  3.86740299e-02 6.29624280e-09 1.90669472e-02 1.72207123e-02
#  8.27524358e-16 1.03228091e-10 2.60257616e-16 1.23048709e+04
#  1.54823079e-12 4.34262932e-07 2.05226514e-01 6.63228449e+00
#  7.66230558e+00 1.13708234e-08 3.09084049e-08 1.44567164e-13
#  3.86362808e-12 5.47970511e-13 2.35131338e+10 3.57365259e-09]

# %%
sns.distplot(np.log10(df_top_thetas_EA[labelnames[3]]))

# %% [markdown]
# # Check ABC - SMC

# %%
base_folder = 'C:/Users/sksuzuki/Documents/GitHub/HOG_encoding_feedbacks/python_modules/ABC_SMC/200121_M3c_ea_abc_smc/'

ea = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0000.hdf5', 'r')

# %%
list(ea.keys())
# Out:
# ['mses', 'thetas']

# %%
ea_thetas = ea['thetas']
ea_mses = ea['mses']

# %%
plotting.plt_param_cis(model_fxns, ea_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Repeated convergence failures (perhaps bad Jacobian or tolerances). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
e1 = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0001.hdf5', 'r')

# %%
e1_thetas = e1['thetas']
e1_mses = e1['mses']

# %%
plotting.plt_param_cis(M2c_fxns, e1_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
e4 = h5py.File(base_folder+'200121_M3c_ea_abc_smc_0004.hdf5', 'r')

e4_thetas = e4['thetas']
e4_mses = e4['mses']

# %%
plotting.plt_param_cis(M2c_fxns, e4_thetas, params_constants, initials,  doses, time, 2,
                        exp_data=mapk_wt_data, exp_time=mapk_time, ss=True, ci='sd',
                        save_fig='test03')
# Out:
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The number of calls to function has reached maxfev = 1000.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Dose: 0 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 50000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 150000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 250000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 350000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 450000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
# Dose: 550000 complete.
# C:\Users\sksuzuki\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
